# %% [markdown]
# <a href="https://colab.research.google.com/github/adarshsalve/DS_PY_Writeups_2001622/blob/main/23A_6655.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing pandas library
import pandas as pd
import numpy
import matplotlib.pyplot as plt
numpy.__version__
# Out:
# '1.22.4'

# %%
from google.colab import drive
drive.mount('/content/My_Drive')
# Out:
# Drive already mounted at /content/My_Drive; to attempt to forcibly remount, call drive.mount("/content/My_Drive", force_remount=True).

# %%
path="/content/My_Drive/MyDrive/Classroom/dataset1.csv"
df=pd.read_csv(path)

# %%
df.describe()
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# count               481        481        481        481        481
# unique              481        123        210         86        181
# top     # Columns: time         36        1.3         16       1.25
# freq                  1         21         19         23         10
#
#        Unnamed: 5 Unnamed: 6
# count         481        481
# unique        102        194
# top            15       2.45
# freq           22         13

# %%
# Load the dataset into Python
import pandas as pd

data = pd.read_csv("/content/My_Drive/MyDrive/Classroom/dataset1.csv")

# Identify the two numeric columns you want to create a subset for
numeric_cols = ["Unnamed: 1","Unnamed: 3"]

# Select only those two columns and create a new dataframe
subset_data = data[numeric_cols]

# Store the new dataframe in a separate variable
subset_variable = subset_data

# Show a statistical summary of the two columns
print(subset_data.describe())

# Check for missing values in the two columns
print(subset_data.isna().sum())
# Out:
#        Unnamed: 1 Unnamed: 3
# count         481        481
# unique        123         86
# top            36         16
# freq           21         23
# Unnamed: 1    3
# Unnamed: 3    3
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns

# Load the dataset
op= pd.read_csv("/content/My_Drive/MyDrive/Classroom/dataset1.csv")

# Create a scatter plot of serum creatinine vs. ejection fraction
sns.scatterplot(x="Unnamed: 1", y="Unnamed: 2", data=op)
# Out:
# <Axes: xlabel='Unnamed: 1', ylabel='Unnamed: 2'>
